# %%
import pandas as pd
dframe = pd.read_csv("Downloads/archive (1)/ai_student_impact_dataset (1).csv")
print(dframe)
print(dframe.head())
dframe.shape
dframe.iloc[2:,2]
dframe.iloc[2:5,[0,1,2,5,9]]
dframe.set_index("Year_of_Study")
dframe.loc[0:2,['Student_ID','Year_of_Study']]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
import pandas as pd
dframe = pd.read_csv("Downloads/archive (1)/ai_student_impact_dataset (1).csv")
dframe.loc[:,['Student_ID','Pre_Semester_GPA','Year_of_Study']]
dframe.columns
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours',
#        'Perceived_AI_Dependency', 'Institutional_Policy',
#        'Anxiety_Level_During_Exams', 'Post_Semester_GPA',
#        'Skill_Retention_Score', 'Burnout_Risk_Level'],
#       dtype='object')

# %%
import pandas as pd
dframe = pd.read_csv("Downloads/archive (1)/ai_student_impact_dataset (1).csv")
dframe.loc[:,'Year_of_Study']==2008
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Name: Year_of_Study, Length: 50000, dtype: bool

# %%
import pandas as pd
dframe = pd.read_csv("Downloads/archive (1)/ai_student_impact_dataset (1).csv")
filt=dframe['Burnout_Risk_Level']== 'Low'
dframe.loc[filt].head
dframe.loc[filt].sort_index().head()
wdf=dframe.loc[filt].sort_index(ascending=False).head()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49999      150000           Arts     Sophomore             3.242
# 49992      149993       Business      Graduate             2.829
# 49988      149989           STEM     Sophomore             2.058
# 49987      149988     Humanities        Junior             2.980
# 49985      149986     Humanities     Sophomore             3.661
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 49999                3.30       Copywriting/Drafting                 Beginner
# 49992                2.59  Debugging/Troubleshooting                 Advanced
# 49988                3.32  Debugging/Troubleshooting                 Beginner
# 49987                0.50   Direct_Answer_Generation             Intermediate
# 49985                1.91       Copywriting/Drafting                 Beginner
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# ...
